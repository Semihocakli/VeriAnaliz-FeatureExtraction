# %%
import pandas as pd

# %%
def MyFunction(number):
  print("hello world " + str(number))


MyFunction(16)
# Out:
# hello world 16

# %%
class MyClass:
  def __init__(self):
    self.objectData=576

  def printObjectData(self):
    print(self.objectData)
    return self.objectData

# %%
Object1= MyClass()
print("Object1 veri üyesi:", Object1.objectData)

# MyClass örneğinin veri üyesini yazdırmak için fonksiyonu çağırın
Object1.printObjectData()
# Out:
# Object1 veri üyesi: 576
# 576
# 576

# %%
dataframe = pd.read_csv('/saglikhizmetleri.csv')

# %%
dataframe.head()
# Out:
#    _id                                           KONU                    ILCE  \
# 0    1                     İNAYET TOPÇUOĞLU HASTANESİ  Tüm İl baz alınmıştır.
# 1    2                             EVDE FİZİK TEDAVİ   Tüm İl baz alınmıştır.
# 2    3  MOBİL AĞIZ VE DİŞ SAĞLIĞI TEŞHİS TEDAVİ ARACI  Tüm İl baz alınmıştır.
# 3    4                      TÜP BEBEK MERKEZİ HİZMET   Tüm İl baz alınmıştır.
# 4    5                              ANNE OTELİ HİZMET  Tüm İl baz alınmıştır.
#
#       MIKTAR BIRIM
# 0  6.683.612  KİŞİ
# 1       2319  KİŞİ
# 2       6712  KİŞİ
# 3     11.131  KİŞİ
# 4      7.223  KİŞİ
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...
